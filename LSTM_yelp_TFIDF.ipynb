# %% [markdown]
# Mounting my stuff first from google drive, as I used Google Colab for this.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Just a sanity check over here.

# %%
# !ls /content/drive/My\ Drive/yelp
# Out:
# 'Dataset preparation.ipynb'   my_yelp_data.csv
# 'LSTM yelp TFIDF.ipynb'       yelp_review.csv

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import gensim
from sklearn.linear_model import LogisticRegression
from gensim.models.doc2vec import TaggedDocument
from sklearn import utils
import numpy as np

# %% [markdown]
# The CSV for the yelp data has been slightly modified. The link to the CSV can be found in the readme of the GIT

# %%
df = pd.read_csv("/content/drive/My Drive/yelp/my_yelp_data.csv")

# %% [markdown]
# What we want to do here is to do a time series prediction based on the reviews of customers.
# <br>
# <br>
# Let's consider that we have some hotels with unique hotel ids. Some of the hotels have been closed and some of the hotels are still open. We have some reviews for each of the hotels ids from customers over a date. In this dataset, we have one review per date for each hotel id and we have 10 such reviews. We also have stars given for each of the unique hotels. Consider that stars are not the rating of the review that is posted, but the rating of the hotel overall.
# <br>
# <br>
# There can also be a different format for this. For instance, multiple reviews can be posted on the same date. We just need to keep in mind that we need sorted reviews by date-time in order to use this approach. You can always sort the reviews according to a column name in pandas.
# <br>
# <br>
# This is how the Dataframe looks like.

# %%
df.head()
# Out:
#          date  ...                                               text
# 0  2016-05-28  ...  Super simple place but amazing nonetheless. It...
# 1  2016-05-29  ...  Small unassuming place that changes their menu...
# 2  2016-05-30  ...  Lester's is located in a beautiful neighborhoo...
# 3  2016-05-31  ...  Love coming here. Yes the place always needs t...
# 4  2016-06-01  ...  Had their chocolate almond croissant and it wa...
#
# [5 rows x 4 columns]

# %% [markdown]
# We want to predict if the business will be closed or not base on the reviews. A metric for that would be based on the stars. Let's say that the hotels with a rating less than 3 are shut down and those with ratings more than 3 are open. We'll add another column in the dataframe which will map this condition from the stars.
# <br>
# <br>
# I might use the words 'notes' and 'reviews' in this notebook. Please consider that both of them are same and they are referring to the column "text" in the dataframe. Don't get confused.

# %%
df['business_closed'] = df['stars'].map(lambda x : 1 if x < 3 else 0)

# %% [markdown]
# This is how the DataFrame looks now.

# %%
df.head()
# Out:
#          date  ...  business_closed
# 0  2016-05-28  ...                0
# 1  2016-05-29  ...                0
# 2  2016-05-30  ...                0
# 3  2016-05-31  ...                0
# 4  2016-06-01  ...                0
#
# [5 rows x 5 columns]

# %% [markdown]
# Just cleaning the text over here. Removing stop words, removing unwanted characters like . ; : and so on. Also tokenizing the sentence.

# %%
def cleanText(text):
    from bs4 import BeautifulSoup
    import re
    import string
    text = BeautifulSoup(text, "lxml").text
    text = text.replace('\n','')
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\|\|\|', r' ', text) 
    text = re.sub(r'http\S+', r'<URL>', text)
    text = text.lower()
    text = text.replace('x', '')
    return text

# %%
full_cleaned = [cleanText(i) for i in df['text']]

# %% [markdown]
# This is how the cleaned text looks like.

# %%
df['text'][0]
# Out:
# "Super simple place but amazing nonetheless. It's been around since the 30's and they still serve the same thing they started with: a bologna and salami sandwich with mustard. \n\nStaff was very helpful and friendly."

# %%
full_cleaned[0]
# Out:
# 'super simple place but amazing nonetheless its been around since the 30s and they still serve the same thing they started with a bologna and salami sandwich with mustard staff was very helpful and friendly'

# %% [markdown]
# Converting the clean text with Count Vectorizer and transformer. This is how the text is converted to TFIDF.

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer(max_features = 100)#We are extracting only 100 features for our text.
#You can change this number according to your own dataset.
X_train_counts = count_vect.fit_transform(full_cleaned)

# %% [markdown]
# These are the standard steps for getting TFIDF features of a text. For more info regarding this check [this](https://stackoverflow.com/questions/36800654/how-is-the-tfidfvectorizer-in-scikit-learn-supposed-to-work).
# <br>
# As we have used number of features as 100 in the previous step, our data will have dimensions as 1000,100 as the number of reviews is 1000 and their 100 dimensions, which is shown as the output of this cell.

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (10000, 100)

# %% [markdown]
# Converting the list to an array, for use in Keras.

# %%
X_train_tfidf = X_train_tfidf.toarray()

# %% [markdown]
# Let's say you have around 100 notes per hotel which are arranged in time series. You want to consider just the latest 10 or 20 notes before the hotel closed. You would then take the last 10 or 20 notes in the dataframe for each hotel id. The variable
# ```
# notes_per_hotel_taken
# ```
# considers how many notes you want to consider and takes the latest notes of that number for each hotel.

# %%
notes_per_hotel_taken = 8

# %% [markdown]
# In our example, we have 10 notes per hotel. Let's say we wish to look at only the latest 8 notes. So, we are now using the latest 8 notes for each hotel id.

# %%
unique_hotelids = df['hotel_id'].unique()
notes_per_hotel_id = {} #This will store the lates 8 notes for each hotel_id.
notes_per_hotel_id_full = {} #This will store all the notes for each hotel_id, irrespective of the 
#notes that we've decided to take before.

for i in unique_hotelids:
  temp = df[df['hotel_id'] == i].tail(notes_per_hotel_taken)#Taking the last 8 i.e latest 8 notes of the hotel.
  temp1 = df[df['hotel_id'] == i]
  
  temp_list = [X_train_tfidf[j] for j in temp.index]#appending the latest 8 notes in a list
  temp1_list = [X_train_tfidf[j] for j in temp1.index]#appending all the notes of the hotel id in the list.
  
  notes_per_hotel_id[i] = temp_list #appending just the 8 notes per hotel id
  notes_per_hotel_id_full[i] = temp1_list #appending all the notes
  """
  now dictionary will be like this 
  notes_per_hotel_id = {2 : ['first note', 'second note'.. upto 8 notes]}
  for each hotel_id
  This will directly contain the vectors of each note and not the text of the notes
  """

# %% [markdown]
# There can also be some hotels who do not 8 latest review. They may just have 3 or 4 latest review for a hotel (in our dataset, there is no such case). But just in case there is, then we have padded 0.
# <br>
# <br>
# Consider that for hotel_id = 4, there are just 4 reviews present. But earlier we have determined that notes_per_hotel_taken is 8. That is we need 8 notes per hotel. So in order to make our input uniform for the LSTM, we add zero padding. The zero padding should match the dimension of our rest of the reviews, remember that we have used 100 as dimension for TFIDF.
# <br>
# So now, for hotel_id = 4, our list of notes would be [0, 0, 0, 0, note1,  note2,  note3,  note 4].
# <br>
# In this way, we make our input uniform.

# %%
import numpy as np

for i in unique_hotelids:
  if len(notes_per_hotel_id[i]) < notes_per_hotel_taken:#checking if length of reviews for 
    #a hotel id is less than the length that we determined before.
    number_of_padded_lists = notes_per_hotel_taken - len(notes_per_hotel_id[i])
    #How many padded zeros will be required for that hotel_id
    t = [np.zeros(100, dtype = float) for i in range(number_of_padded_lists)]
    #Getting padded lists, with 100 as dimension for our TFIDF is 100, Change this according to your dimension of TFIDF.
    notes_per_hotel_id[i] = np.array(t + notes_per_hotel_id[i])
    #Appending and making the input uniform.

# %% [markdown]
# Setting parameters for the model.

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import numpy as np

data_dim = 100
number_of_notes_per_hotel = notes_per_hotel_taken
n_notes_train = len(notes_per_hotel_id)
#tunable parameter
batch_size = 50
epochs = 5

# %% [markdown]
# Getting the features and the labels for our model.

# %%
x_train_lstm = np.array([notes_per_hotel_id[i] for i in notes_per_hotel_id])
y_lstm = []
for i in unique_hotelids:
  temp = df[df['hotel_id'] == i]['business_closed']
  temp.index = range(len(temp))
  y_lstm.append(temp[0])
  
y_lstm = np.array(y_lstm)

# %%
print("Length of train set is",len(x_train_lstm))
print("Length of label set is",len(y_lstm))
# Out:
# Length of train set is 1000
# Length of label set is 1000

# %% [markdown]
# Model architecture

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(None, data_dim),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

# %% [markdown]
# Setting 200 data points for validation.

# %%
model.fit(x_train_lstm[0:800],y_lstm[0:800], validation_data = (x_train_lstm[800:],y_lstm[800:]), batch_size=batch_size, epochs=epochs)
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4080 - acc: 0.8462 - val_loss: 0.5261 - val_acc: 0.7950
# Epoch 2/5
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3844 - acc: 0.8587 - val_loss: 0.5531 - val_acc: 0.7850
# Epoch 3/5
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3515 - acc: 0.8587 - val_loss: 0.6136 - val_acc: 0.7850
# Epoch 4/5
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3613 - acc: 0.8500 - val_loss: 0.5200 - val_acc: 0.7950
# Epoch 5/5
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3443 - acc: 0.8587 - val_loss: 0.5323 - val_acc: 0.7850

# %% [markdown]
# For predicting on a datapoint, we would again want to consider the lates 8 notes for each hotels.

# %%
all_notevectors = [notes_per_hotel_id_full[i] for i in notes_per_hotel_id_full]
all_notevectors = [j for i in all_notevectors for j in i]

# %% [markdown]
# Running the prediction again of the reviews that were used for training the model, (for an example)

# %%
prediction_array = []
k = 0

for i in unique_hotelids:
  print("Now processing ", k, "subject id out of ", len(unique_hotelids))  
  t = df[df['hotel_id'] == i]
  if len(t) == 1:
    idx = t.index[0]
    preds = model.predict_proba([[[all_notevectors[idx]]]])
    prediction_array.append(preds)
  else:
    first_idx = t.index[0]
    for j in t.index[1:]:
      preds = model.predict_proba([[all_notevectors[first_idx : j]]])
      prediction_array.append(preds)
    last_idx = t.index[-1] + 1
    preds = model.predict_proba([[all_notevectors[first_idx : last_idx]]])
    prediction_array.append(preds)
    
  k += 1
# Out:
# Now processing  0 subject id out of  1000
# Now processing  1 subject id out of  1000
# Now processing  2 subject id out of  1000
# Now processing  3 subject id out of  1000
# Now processing  4 subject id out of  1000
# Now processing  5 subject id out of  1000
# Now processing  6 subject id out of  1000
# Now processing  7 subject id out of  1000
# Now processing  8 subject id out of  1000
# Now processing  9 subject id out of  1000
# Now processing  10 subject id out of  1000
# Now processing  11 subject id out of  1000
# Now processing  12 subject id out of  1000
# Now processing  13 subject id out of  1000
# Now processing  14 subject id out of  1000
# Now processing  15 subject id out of  1000
# Now processing  16 subject id out of  1000
# Now processing  17 subject id out of  1000
# Now processing  18 subject id out of  1000
# Now processing  19 subject id out of  1000
# Now processing  20 subject id out of  1000
# Now processing  21 subject id out of  1000
# Now processing  22 subject id out of  1000
# Now processing  23 subject id out of  1000
# Now processing  24 subject id out of  1000
# Now processing  25 subject id out of  1000
# Now processing  26 subject id out of  1000
# Now processing  27 subject id out of  1000
# Now processing  28 subject id out of  1000
# Now processing  29 subject id out of  1000
# Now processing  30 subject id out of  1000
# Now processing  31 subject id out of  1000
# Now processing  32 subject id out of  1000
# Now processing  33 subject id out of  1000
# Now processing  34 subject id out of  1000
# Now processing  35 subject id out of  1000
# Now processing  36 subject id out of  1000
# Now processing  37 subject id out of  1000
# Now processing  38 subject id out of  1000
# Now processing  39 subject id out of  1000
# Now processing  40 subject id out of  1000
# Now processing  41 subject id out of  1000
# Now processing  42 subject id out of  1000
# Now processing  43 subject id out of  1000
# Now processing  44 subject id out of  1000
# Now processing  45 subject id out of  1000
# Now processing  46 subject id out of  1000
# Now processing  47 subject id out of  1000
# Now processing  48 subject id out of  1000
# Now processing  49 subject id out of  1000
# Now processing  50 subject id out of  1000
# Now processing  51 subject id out of  1000
# Now processing  52 subject id out of  1000
# Now processing  53 subject id out of  1000
# Now processing  54 subject id out of  1000
# Now processing  55 subject id out of  1000
# Now processing  56 subject id out of  1000
# Now processing  57 subject id out of  1000
# Now processing  58 subject id out of  1000
# Now processing  59 subject id out of  1000
# Now processing  60 subject id out of  1000
# Now processing  61 subject id out of  1000
# Now processing  62 subject id out of  1000
# Now processing  63 subject id out of  1000
# Now processing  64 subject id out of  1000
# Now processing  65 subject id out of  1000
# Now processing  66 subject id out of  1000
# Now processing  67 subject id out of  1000
# Now processing  68 subject id out of  1000
# Now processing  69 subject id out of  1000
# Now processing  70 subject id out of  1000
# Now processing  71 subject id out of  1000
# Now processing  72 subject id out of  1000
# Now processing  73 subject id out of  1000
# Now processing  74 subject id out of  1000
# Now processing  75 subject id out of  1000
# Now processing  76 subject id out of  1000
# Now processing  77 subject id out of  1000
# Now processing  78 subject id out of  1000
# Now processing  79 subject id out of  1000
# Now processing  80 subject id out of  1000
# Now processing  81 subject id out of  1000
# Now processing  82 subject id out of  1000
# Now processing  83 subject id out of  1000
# Now processing  84 subject id out of  1000
# Now processing  85 subject id out of  1000
# Now processing  86 subject id out of  1000
# Now processing  87 subject id out of  1000
# Now processing  88 subject id out of  1000
# Now processing  89 subject id out of  1000
# Now processing  90 subject id out of  1000
# Now processing  91 subject id out of  1000
# Now processing  92 subject id out of  1000
# Now processing  93 subject id out of  1000
# Now processing  94 subject id out of  1000
# Now processing  95 subject id out of  1000
# Now processing  96 subject id out of  1000
# Now processing  97 subject id out of  1000
# Now processing  98 subject id out of  1000
# Now processing  99 subject id out of  1000
# Now processing  100 subject id out of  1000
# Now processing  101 subject id out of  1000
# Now processing  102 subject id out of  1000
# Now processing  103 subject id out of  1000
# Now processing  104 subject id out of  1000
# Now processing  105 subject id out of  1000
# Now processing  106 subject id out of  1000
# Now processing  107 subject id out of  1000
# Now processing  108 subject id out of  1000
# Now processing  109 subject id out of  1000
# Now processing  110 subject id out of  1000
# Now processing  111 subject id out of  1000
# Now processing  112 subject id out of  1000
# Now processing  113 subject id out of  1000
# Now processing  114 subject id out of  1000
# Now processing  115 subject id out of  1000
# Now processing  116 subject id out of  1000
# Now processing  117 subject id out of  1000
# Now processing  118 subject id out of  1000
# Now processing  119 subject id out of  1000
# Now processing  120 subject id out of  1000
# Now processing  121 subject id out of  1000
# Now processing  122 subject id out of  1000
# Now processing  123 subject id out of  1000
# Now processing  124 subject id out of  1000
# Now processing  125 subject id out of  1000
# Now processing  126 subject id out of  1000
# Now processing  127 subject id out of  1000
# Now processing  128 subject id out of  1000
# Now processing  129 subject id out of  1000
# Now processing  130 subject id out of  1000
# Now processing  131 subject id out of  1000
# Now processing  132 subject id out of  1000
# Now processing  133 subject id out of  1000
# Now processing  134 subject id out of  1000
# Now processing  135 subject id out of  1000
# Now processing  136 subject id out of  1000
# Now processing  137 subject id out of  1000
# Now processing  138 subject id out of  1000
# Now processing  139 subject id out of  1000
# Now processing  140 subject id out of  1000
# Now processing  141 subject id out of  1000
# Now processing  142 subject id out of  1000
# Now processing  143 subject id out of  1000
# Now processing  144 subject id out of  1000
# Now processing  145 subject id out of  1000
# Now processing  146 subject id out of  1000
# Now processing  147 subject id out of  1000
# Now processing  148 subject id out of  1000
# Now processing  149 subject id out of  1000
# Now processing  150 subject id out of  1000
# Now processing  151 subject id out of  1000
# Now processing  152 subject id out of  1000
# Now processing  153 subject id out of  1000
# Now processing  154 subject id out of  1000
# Now processing  155 subject id out of  1000
# Now processing  156 subject id out of  1000
# Now processing  157 subject id out of  1000
# Now processing  158 subject id out of  1000
# Now processing  159 subject id out of  1000
# Now processing  160 subject id out of  1000
# Now processing  161 subject id out of  1000
# Now processing  162 subject id out of  1000
# Now processing  163 subject id out of  1000
# Now processing  164 subject id out of  1000
# Now processing  165 subject id out of  1000
# Now processing  166 subject id out of  1000
# Now processing  167 subject id out of  1000
# Now processing  168 subject id out of  1000
# Now processing  169 subject id out of  1000
# Now processing  170 subject id out of  1000
# Now processing  171 subject id out of  1000
# Now processing  172 subject id out of  1000
# Now processing  173 subject id out of  1000
# Now processing  174 subject id out of  1000
# Now processing  175 subject id out of  1000
# Now processing  176 subject id out of  1000
# Now processing  177 subject id out of  1000
# Now processing  178 subject id out of  1000
# Now processing  179 subject id out of  1000
# Now processing  180 subject id out of  1000
# Now processing  181 subject id out of  1000
# Now processing  182 subject id out of  1000
# Now processing  183 subject id out of  1000
# Now processing  184 subject id out of  1000
# Now processing  185 subject id out of  1000
# Now processing  186 subject id out of  1000
# Now processing  187 subject id out of  1000
# Now processing  188 subject id out of  1000
# Now processing  189 subject id out of  1000
# Now processing  190 subject id out of  1000
# Now processing  191 subject id out of  1000
# Now processing  192 subject id out of  1000
# Now processing  193 subject id out of  1000
# Now processing  194 subject id out of  1000
# Now processing  195 subject id out of  1000
# Now processing  196 subject id out of  1000
# Now processing  197 subject id out of  1000
# Now processing  198 subject id out of  1000
# Now processing  199 subject id out of  1000
# Now processing  200 subject id out of  1000
# Now processing  201 subject id out of  1000
# Now processing  202 subject id out of  1000
# Now processing  203 subject id out of  1000
# Now processing  204 subject id out of  1000
# Now processing  205 subject id out of  1000
# Now processing  206 subject id out of  1000
# Now processing  207 subject id out of  1000
# Now processing  208 subject id out of  1000
# Now processing  209 subject id out of  1000
# Now processing  210 subject id out of  1000
# Now processing  211 subject id out of  1000
# Now processing  212 subject id out of  1000
# Now processing  213 subject id out of  1000
# Now processing  214 subject id out of  1000
# Now processing  215 subject id out of  1000
# Now processing  216 subject id out of  1000
# Now processing  217 subject id out of  1000
# Now processing  218 subject id out of  1000
# Now processing  219 subject id out of  1000
# Now processing  220 subject id out of  1000
# Now processing  221 subject id out of  1000
# Now processing  222 subject id out of  1000
# Now processing  223 subject id out of  1000
# Now processing  224 subject id out of  1000
# Now processing  225 subject id out of  1000
# Now processing  226 subject id out of  1000
# Now processing  227 subject id out of  1000
# Now processing  228 subject id out of  1000
# Now processing  229 subject id out of  1000
# Now processing  230 subject id out of  1000
# Now processing  231 subject id out of  1000
# Now processing  232 subject id out of  1000
# Now processing  233 subject id out of  1000
# Now processing  234 subject id out of  1000
# Now processing  235 subject id out of  1000
# Now processing  236 subject id out of  1000
# Now processing  237 subject id out of  1000
# Now processing  238 subject id out of  1000
# Now processing  239 subject id out of  1000
# Now processing  240 subject id out of  1000
# Now processing  241 subject id out of  1000
# Now processing  242 subject id out of  1000
# Now processing  243 subject id out of  1000
# Now processing  244 subject id out of  1000
# Now processing  245 subject id out of  1000
# Now processing  246 subject id out of  1000
# Now processing  247 subject id out of  1000
# Now processing  248 subject id out of  1000
# Now processing  249 subject id out of  1000
# Now processing  250 subject id out of  1000
# Now processing  251 subject id out of  1000
# Now processing  252 subject id out of  1000
# Now processing  253 subject id out of  1000
# Now processing  254 subject id out of  1000
# Now processing  255 subject id out of  1000
# Now processing  256 subject id out of  1000
# Now processing  257 subject id out of  1000
# Now processing  258 subject id out of  1000
# Now processing  259 subject id out of  1000
# Now processing  260 subject id out of  1000
# Now processing  261 subject id out of  1000
# Now processing  262 subject id out of  1000
# Now processing  263 subject id out of  1000
# Now processing  264 subject id out of  1000
# Now processing  265 subject id out of  1000
# Now processing  266 subject id out of  1000
# Now processing  267 subject id out of  1000
# Now processing  268 subject id out of  1000
# Now processing  269 subject id out of  1000
# Now processing  270 subject id out of  1000
# Now processing  271 subject id out of  1000
# Now processing  272 subject id out of  1000
# Now processing  273 subject id out of  1000
# Now processing  274 subject id out of  1000
# Now processing  275 subject id out of  1000
# Now processing  276 subject id out of  1000
# Now processing  277 subject id out of  1000
# Now processing  278 subject id out of  1000
# Now processing  279 subject id out of  1000
# Now processing  280 subject id out of  1000
# Now processing  281 subject id out of  1000
# Now processing  282 subject id out of  1000
# Now processing  283 subject id out of  1000
# Now processing  284 subject id out of  1000
# Now processing  285 subject id out of  1000
# Now processing  286 subject id out of  1000
# Now processing  287 subject id out of  1000
# Now processing  288 subject id out of  1000
# Now processing  289 subject id out of  1000
# Now processing  290 subject id out of  1000
# Now processing  291 subject id out of  1000
# Now processing  292 subject id out of  1000
# Now processing  293 subject id out of  1000
# Now processing  294 subject id out of  1000
# Now processing  295 subject id out of  1000
# Now processing  296 subject id out of  1000
# Now processing  297 subject id out of  1000
# Now processing  298 subject id out of  1000
# Now processing  299 subject id out of  1000
# Now processing  300 subject id out of  1000
# Now processing  301 subject id out of  1000
# Now processing  302 subject id out of  1000
# Now processing  303 subject id out of  1000
# Now processing  304 subject id out of  1000
# Now processing  305 subject id out of  1000
# Now processing  306 subject id out of  1000
# Now processing  307 subject id out of  1000
# Now processing  308 subject id out of  1000
# Now processing  309 subject id out of  1000
# Now processing  310 subject id out of  1000
# Now processing  311 subject id out of  1000
# Now processing  312 subject id out of  1000
# Now processing  313 subject id out of  1000
# Now processing  314 subject id out of  1000
# Now processing  315 subject id out of  1000
# Now processing  316 subject id out of  1000
# Now processing  317 subject id out of  1000
# Now processing  318 subject id out of  1000
# Now processing  319 subject id out of  1000
# Now processing  320 subject id out of  1000
# Now processing  321 subject id out of  1000
# Now processing  322 subject id out of  1000
# Now processing  323 subject id out of  1000
# Now processing  324 subject id out of  1000
# Now processing  325 subject id out of  1000
# Now processing  326 subject id out of  1000
# Now processing  327 subject id out of  1000
# Now processing  328 subject id out of  1000
# Now processing  329 subject id out of  1000
# Now processing  330 subject id out of  1000
# Now processing  331 subject id out of  1000
# Now processing  332 subject id out of  1000
# Now processing  333 subject id out of  1000
# Now processing  334 subject id out of  1000
# Now processing  335 subject id out of  1000
# Now processing  336 subject id out of  1000
# Now processing  337 subject id out of  1000
# Now processing  338 subject id out of  1000
# Now processing  339 subject id out of  1000
# Now processing  340 subject id out of  1000
# Now processing  341 subject id out of  1000
# Now processing  342 subject id out of  1000
# Now processing  343 subject id out of  1000
# Now processing  344 subject id out of  1000
# Now processing  345 subject id out of  1000
# Now processing  346 subject id out of  1000
# Now processing  347 subject id out of  1000
# Now processing  348 subject id out of  1000
# Now processing  349 subject id out of  1000
# Now processing  350 subject id out of  1000
# Now processing  351 subject id out of  1000
# Now processing  352 subject id out of  1000
# Now processing  353 subject id out of  1000
# Now processing  354 subject id out of  1000
# Now processing  355 subject id out of  1000
# Now processing  356 subject id out of  1000
# Now processing  357 subject id out of  1000
# Now processing  358 subject id out of  1000
# Now processing  359 subject id out of  1000
# Now processing  360 subject id out of  1000
# Now processing  361 subject id out of  1000
# Now processing  362 subject id out of  1000
# Now processing  363 subject id out of  1000
# Now processing  364 subject id out of  1000
# Now processing  365 subject id out of  1000
# Now processing  366 subject id out of  1000
# Now processing  367 subject id out of  1000
# Now processing  368 subject id out of  1000
# Now processing  369 subject id out of  1000
# Now processing  370 subject id out of  1000
# Now processing  371 subject id out of  1000
# Now processing  372 subject id out of  1000
# Now processing  373 subject id out of  1000
# Now processing  374 subject id out of  1000
# Now processing  375 subject id out of  1000
# Now processing  376 subject id out of  1000
# Now processing  377 subject id out of  1000
# Now processing  378 subject id out of  1000
# Now processing  379 subject id out of  1000
# Now processing  380 subject id out of  1000
# Now processing  381 subject id out of  1000
# Now processing  382 subject id out of  1000
# Now processing  383 subject id out of  1000
# Now processing  384 subject id out of  1000
# Now processing  385 subject id out of  1000
# Now processing  386 subject id out of  1000
# Now processing  387 subject id out of  1000
# Now processing  388 subject id out of  1000
# Now processing  389 subject id out of  1000
# Now processing  390 subject id out of  1000
# Now processing  391 subject id out of  1000
# Now processing  392 subject id out of  1000
# Now processing  393 subject id out of  1000
# Now processing  394 subject id out of  1000
# Now processing  395 subject id out of  1000
# Now processing  396 subject id out of  1000
# Now processing  397 subject id out of  1000
# Now processing  398 subject id out of  1000
# Now processing  399 subject id out of  1000
# Now processing  400 subject id out of  1000
# Now processing  401 subject id out of  1000
# Now processing  402 subject id out of  1000
# Now processing  403 subject id out of  1000
# Now processing  404 subject id out of  1000
# Now processing  405 subject id out of  1000
# Now processing  406 subject id out of  1000
# Now processing  407 subject id out of  1000
# Now processing  408 subject id out of  1000
# Now processing  409 subject id out of  1000
# Now processing  410 subject id out of  1000
# Now processing  411 subject id out of  1000
# Now processing  412 subject id out of  1000
# Now processing  413 subject id out of  1000
# Now processing  414 subject id out of  1000
# Now processing  415 subject id out of  1000
# Now processing  416 subject id out of  1000
# Now processing  417 subject id out of  1000
# Now processing  418 subject id out of  1000
# Now processing  419 subject id out of  1000
# Now processing  420 subject id out of  1000
# Now processing  421 subject id out of  1000
# Now processing  422 subject id out of  1000
# Now processing  423 subject id out of  1000
# Now processing  424 subject id out of  1000
# Now processing  425 subject id out of  1000
# Now processing  426 subject id out of  1000
# Now processing  427 subject id out of  1000
# Now processing  428 subject id out of  1000
# Now processing  429 subject id out of  1000
# Now processing  430 subject id out of  1000
# Now processing  431 subject id out of  1000
# Now processing  432 subject id out of  1000
# Now processing  433 subject id out of  1000
# Now processing  434 subject id out of  1000
# Now processing  435 subject id out of  1000
# Now processing  436 subject id out of  1000
# Now processing  437 subject id out of  1000
# Now processing  438 subject id out of  1000
# Now processing  439 subject id out of  1000
# Now processing  440 subject id out of  1000
# Now processing  441 subject id out of  1000
# Now processing  442 subject id out of  1000
# Now processing  443 subject id out of  1000
# Now processing  444 subject id out of  1000
# Now processing  445 subject id out of  1000
# Now processing  446 subject id out of  1000
# Now processing  447 subject id out of  1000
# Now processing  448 subject id out of  1000
# Now processing  449 subject id out of  1000
# Now processing  450 subject id out of  1000
# Now processing  451 subject id out of  1000
# Now processing  452 subject id out of  1000
# Now processing  453 subject id out of  1000
# Now processing  454 subject id out of  1000
# Now processing  455 subject id out of  1000
# Now processing  456 subject id out of  1000
# Now processing  457 subject id out of  1000
# Now processing  458 subject id out of  1000
# Now processing  459 subject id out of  1000
# Now processing  460 subject id out of  1000
# Now processing  461 subject id out of  1000
# Now processing  462 subject id out of  1000
# Now processing  463 subject id out of  1000
# Now processing  464 subject id out of  1000
# Now processing  465 subject id out of  1000
# Now processing  466 subject id out of  1000
# Now processing  467 subject id out of  1000
# Now processing  468 subject id out of  1000
# Now processing  469 subject id out of  1000
# Now processing  470 subject id out of  1000
# Now processing  471 subject id out of  1000
# Now processing  472 subject id out of  1000
# Now processing  473 subject id out of  1000
# Now processing  474 subject id out of  1000
# Now processing  475 subject id out of  1000
# Now processing  476 subject id out of  1000
# Now processing  477 subject id out of  1000
# Now processing  478 subject id out of  1000
# Now processing  479 subject id out of  1000
# Now processing  480 subject id out of  1000
# Now processing  481 subject id out of  1000
# Now processing  482 subject id out of  1000
# Now processing  483 subject id out of  1000
# Now processing  484 subject id out of  1000
# Now processing  485 subject id out of  1000
# Now processing  486 subject id out of  1000
# Now processing  487 subject id out of  1000
# Now processing  488 subject id out of  1000
# Now processing  489 subject id out of  1000
# Now processing  490 subject id out of  1000
# Now processing  491 subject id out of  1000
# Now processing  492 subject id out of  1000
# Now processing  493 subject id out of  1000
# Now processing  494 subject id out of  1000
# Now processing  495 subject id out of  1000
# Now processing  496 subject id out of  1000
# Now processing  497 subject id out of  1000
# Now processing  498 subject id out of  1000
# Now processing  499 subject id out of  1000
# Now processing  500 subject id out of  1000
# Now processing  501 subject id out of  1000
# Now processing  502 subject id out of  1000
# Now processing  503 subject id out of  1000
# Now processing  504 subject id out of  1000
# Now processing  505 subject id out of  1000
# Now processing  506 subject id out of  1000
# Now processing  507 subject id out of  1000
# Now processing  508 subject id out of  1000
# Now processing  509 subject id out of  1000
# Now processing  510 subject id out of  1000
# Now processing  511 subject id out of  1000
# Now processing  512 subject id out of  1000
# Now processing  513 subject id out of  1000
# Now processing  514 subject id out of  1000
# Now processing  515 subject id out of  1000
# Now processing  516 subject id out of  1000
# Now processing  517 subject id out of  1000
# Now processing  518 subject id out of  1000
# Now processing  519 subject id out of  1000
# Now processing  520 subject id out of  1000
# Now processing  521 subject id out of  1000
# Now processing  522 subject id out of  1000
# Now processing  523 subject id out of  1000
# Now processing  524 subject id out of  1000
# Now processing  525 subject id out of  1000
# Now processing  526 subject id out of  1000
# Now processing  527 subject id out of  1000
# Now processing  528 subject id out of  1000
# Now processing  529 subject id out of  1000
# Now processing  530 subject id out of  1000
# Now processing  531 subject id out of  1000
# Now processing  532 subject id out of  1000
# Now processing  533 subject id out of  1000
# Now processing  534 subject id out of  1000
# Now processing  535 subject id out of  1000
# Now processing  536 subject id out of  1000
# Now processing  537 subject id out of  1000
# Now processing  538 subject id out of  1000
# Now processing  539 subject id out of  1000
# Now processing  540 subject id out of  1000
# Now processing  541 subject id out of  1000
# Now processing  542 subject id out of  1000
# Now processing  543 subject id out of  1000
# Now processing  544 subject id out of  1000
# Now processing  545 subject id out of  1000
# Now processing  546 subject id out of  1000
# Now processing  547 subject id out of  1000
# Now processing  548 subject id out of  1000
# Now processing  549 subject id out of  1000
# Now processing  550 subject id out of  1000
# Now processing  551 subject id out of  1000
# Now processing  552 subject id out of  1000
# Now processing  553 subject id out of  1000
# Now processing  554 subject id out of  1000
# Now processing  555 subject id out of  1000
# Now processing  556 subject id out of  1000
# Now processing  557 subject id out of  1000
# Now processing  558 subject id out of  1000
# Now processing  559 subject id out of  1000
# Now processing  560 subject id out of  1000
# Now processing  561 subject id out of  1000
# Now processing  562 subject id out of  1000
# Now processing  563 subject id out of  1000
# Now processing  564 subject id out of  1000
# Now processing  565 subject id out of  1000
# Now processing  566 subject id out of  1000
# Now processing  567 subject id out of  1000
# Now processing  568 subject id out of  1000
# Now processing  569 subject id out of  1000
# Now processing  570 subject id out of  1000
# Now processing  571 subject id out of  1000
# Now processing  572 subject id out of  1000
# Now processing  573 subject id out of  1000
# Now processing  574 subject id out of  1000
# Now processing  575 subject id out of  1000
# Now processing  576 subject id out of  1000
# Now processing  577 subject id out of  1000
# Now processing  578 subject id out of  1000
# Now processing  579 subject id out of  1000
# Now processing  580 subject id out of  1000
# Now processing  581 subject id out of  1000
# Now processing  582 subject id out of  1000
# Now processing  583 subject id out of  1000
# Now processing  584 subject id out of  1000
# Now processing  585 subject id out of  1000
# Now processing  586 subject id out of  1000
# Now processing  587 subject id out of  1000
# Now processing  588 subject id out of  1000
# Now processing  589 subject id out of  1000
# Now processing  590 subject id out of  1000
# Now processing  591 subject id out of  1000
# Now processing  592 subject id out of  1000
# Now processing  593 subject id out of  1000
# Now processing  594 subject id out of  1000
# Now processing  595 subject id out of  1000
# Now processing  596 subject id out of  1000
# Now processing  597 subject id out of  1000
# Now processing  598 subject id out of  1000
# Now processing  599 subject id out of  1000
# Now processing  600 subject id out of  1000
# Now processing  601 subject id out of  1000
# Now processing  602 subject id out of  1000
# Now processing  603 subject id out of  1000
# Now processing  604 subject id out of  1000
# Now processing  605 subject id out of  1000
# Now processing  606 subject id out of  1000
# Now processing  607 subject id out of  1000
# Now processing  608 subject id out of  1000
# Now processing  609 subject id out of  1000
# Now processing  610 subject id out of  1000
# Now processing  611 subject id out of  1000
# Now processing  612 subject id out of  1000
# Now processing  613 subject id out of  1000
# Now processing  614 subject id out of  1000
# Now processing  615 subject id out of  1000
# Now processing  616 subject id out of  1000
# Now processing  617 subject id out of  1000
# Now processing  618 subject id out of  1000
# Now processing  619 subject id out of  1000
# Now processing  620 subject id out of  1000
# Now processing  621 subject id out of  1000
# Now processing  622 subject id out of  1000
# Now processing  623 subject id out of  1000
# Now processing  624 subject id out of  1000
# Now processing  625 subject id out of  1000
# Now processing  626 subject id out of  1000
# Now processing  627 subject id out of  1000
# Now processing  628 subject id out of  1000
# Now processing  629 subject id out of  1000
# Now processing  630 subject id out of  1000
# Now processing  631 subject id out of  1000
# Now processing  632 subject id out of  1000
# Now processing  633 subject id out of  1000
# Now processing  634 subject id out of  1000
# Now processing  635 subject id out of  1000
# Now processing  636 subject id out of  1000
# Now processing  637 subject id out of  1000
# Now processing  638 subject id out of  1000
# Now processing  639 subject id out of  1000
# Now processing  640 subject id out of  1000
# Now processing  641 subject id out of  1000
# Now processing  642 subject id out of  1000
# Now processing  643 subject id out of  1000
# Now processing  644 subject id out of  1000
# Now processing  645 subject id out of  1000
# Now processing  646 subject id out of  1000
# Now processing  647 subject id out of  1000
# Now processing  648 subject id out of  1000
# Now processing  649 subject id out of  1000
# Now processing  650 subject id out of  1000
# Now processing  651 subject id out of  1000
# Now processing  652 subject id out of  1000
# Now processing  653 subject id out of  1000
# Now processing  654 subject id out of  1000
# Now processing  655 subject id out of  1000
# Now processing  656 subject id out of  1000
# Now processing  657 subject id out of  1000
# Now processing  658 subject id out of  1000
# Now processing  659 subject id out of  1000
# Now processing  660 subject id out of  1000
# Now processing  661 subject id out of  1000
# Now processing  662 subject id out of  1000
# Now processing  663 subject id out of  1000
# Now processing  664 subject id out of  1000
# Now processing  665 subject id out of  1000
# Now processing  666 subject id out of  1000
# Now processing  667 subject id out of  1000
# Now processing  668 subject id out of  1000
# Now processing  669 subject id out of  1000
# Now processing  670 subject id out of  1000
# Now processing  671 subject id out of  1000
# Now processing  672 subject id out of  1000
# Now processing  673 subject id out of  1000
# Now processing  674 subject id out of  1000
# Now processing  675 subject id out of  1000
# Now processing  676 subject id out of  1000
# Now processing  677 subject id out of  1000
# Now processing  678 subject id out of  1000
# Now processing  679 subject id out of  1000
# Now processing  680 subject id out of  1000
# Now processing  681 subject id out of  1000
# Now processing  682 subject id out of  1000
# Now processing  683 subject id out of  1000
# Now processing  684 subject id out of  1000
# Now processing  685 subject id out of  1000
# Now processing  686 subject id out of  1000
# Now processing  687 subject id out of  1000
# Now processing  688 subject id out of  1000
# Now processing  689 subject id out of  1000
# Now processing  690 subject id out of  1000
# Now processing  691 subject id out of  1000
# Now processing  692 subject id out of  1000
# Now processing  693 subject id out of  1000
# Now processing  694 subject id out of  1000
# Now processing  695 subject id out of  1000
# Now processing  696 subject id out of  1000
# Now processing  697 subject id out of  1000
# Now processing  698 subject id out of  1000
# Now processing  699 subject id out of  1000
# Now processing  700 subject id out of  1000
# Now processing  701 subject id out of  1000
# Now processing  702 subject id out of  1000
# Now processing  703 subject id out of  1000
# Now processing  704 subject id out of  1000
# Now processing  705 subject id out of  1000
# Now processing  706 subject id out of  1000
# Now processing  707 subject id out of  1000
# Now processing  708 subject id out of  1000
# Now processing  709 subject id out of  1000
# Now processing  710 subject id out of  1000
# Now processing  711 subject id out of  1000
# Now processing  712 subject id out of  1000
# Now processing  713 subject id out of  1000
# Now processing  714 subject id out of  1000
# Now processing  715 subject id out of  1000
# Now processing  716 subject id out of  1000
# Now processing  717 subject id out of  1000
# Now processing  718 subject id out of  1000
# Now processing  719 subject id out of  1000
# Now processing  720 subject id out of  1000
# Now processing  721 subject id out of  1000
# Now processing  722 subject id out of  1000
# Now processing  723 subject id out of  1000
# Now processing  724 subject id out of  1000
# Now processing  725 subject id out of  1000
# Now processing  726 subject id out of  1000
# Now processing  727 subject id out of  1000
# Now processing  728 subject id out of  1000
# Now processing  729 subject id out of  1000
# Now processing  730 subject id out of  1000
# Now processing  731 subject id out of  1000
# Now processing  732 subject id out of  1000
# Now processing  733 subject id out of  1000
# Now processing  734 subject id out of  1000
# Now processing  735 subject id out of  1000
# Now processing  736 subject id out of  1000
# Now processing  737 subject id out of  1000
# Now processing  738 subject id out of  1000
# Now processing  739 subject id out of  1000
# Now processing  740 subject id out of  1000
# Now processing  741 subject id out of  1000
# Now processing  742 subject id out of  1000
# Now processing  743 subject id out of  1000
# Now processing  744 subject id out of  1000
# Now processing  745 subject id out of  1000
# Now processing  746 subject id out of  1000
# Now processing  747 subject id out of  1000
# Now processing  748 subject id out of  1000
# Now processing  749 subject id out of  1000
# Now processing  750 subject id out of  1000
# Now processing  751 subject id out of  1000
# Now processing  752 subject id out of  1000
# Now processing  753 subject id out of  1000
# Now processing  754 subject id out of  1000
# Now processing  755 subject id out of  1000
# Now processing  756 subject id out of  1000
# Now processing  757 subject id out of  1000
# Now processing  758 subject id out of  1000
# Now processing  759 subject id out of  1000
# Now processing  760 subject id out of  1000
# Now processing  761 subject id out of  1000
# Now processing  762 subject id out of  1000
# Now processing  763 subject id out of  1000
# Now processing  764 subject id out of  1000
# Now processing  765 subject id out of  1000
# Now processing  766 subject id out of  1000
# Now processing  767 subject id out of  1000
# Now processing  768 subject id out of  1000
# Now processing  769 subject id out of  1000
# Now processing  770 subject id out of  1000
# Now processing  771 subject id out of  1000
# Now processing  772 subject id out of  1000
# Now processing  773 subject id out of  1000
# Now processing  774 subject id out of  1000
# Now processing  775 subject id out of  1000
# Now processing  776 subject id out of  1000
# Now processing  777 subject id out of  1000
# Now processing  778 subject id out of  1000
# Now processing  779 subject id out of  1000
# Now processing  780 subject id out of  1000
# Now processing  781 subject id out of  1000
# Now processing  782 subject id out of  1000
# Now processing  783 subject id out of  1000
# Now processing  784 subject id out of  1000
# Now processing  785 subject id out of  1000
# Now processing  786 subject id out of  1000
# Now processing  787 subject id out of  1000
# Now processing  788 subject id out of  1000
# Now processing  789 subject id out of  1000
# Now processing  790 subject id out of  1000
# Now processing  791 subject id out of  1000
# Now processing  792 subject id out of  1000
# Now processing  793 subject id out of  1000
# Now processing  794 subject id out of  1000
# Now processing  795 subject id out of  1000
# Now processing  796 subject id out of  1000
# Now processing  797 subject id out of  1000
# Now processing  798 subject id out of  1000
# Now processing  799 subject id out of  1000
# Now processing  800 subject id out of  1000
# Now processing  801 subject id out of  1000
# Now processing  802 subject id out of  1000
# Now processing  803 subject id out of  1000
# Now processing  804 subject id out of  1000
# Now processing  805 subject id out of  1000
# Now processing  806 subject id out of  1000
# Now processing  807 subject id out of  1000
# Now processing  808 subject id out of  1000
# Now processing  809 subject id out of  1000
# Now processing  810 subject id out of  1000
# Now processing  811 subject id out of  1000
# Now processing  812 subject id out of  1000
# Now processing  813 subject id out of  1000
# Now processing  814 subject id out of  1000
# Now processing  815 subject id out of  1000
# Now processing  816 subject id out of  1000
# Now processing  817 subject id out of  1000
# Now processing  818 subject id out of  1000
# Now processing  819 subject id out of  1000
# Now processing  820 subject id out of  1000
# Now processing  821 subject id out of  1000
# Now processing  822 subject id out of  1000
# Now processing  823 subject id out of  1000
# Now processing  824 subject id out of  1000
# Now processing  825 subject id out of  1000
# Now processing  826 subject id out of  1000
# Now processing  827 subject id out of  1000
# Now processing  828 subject id out of  1000
# Now processing  829 subject id out of  1000
# Now processing  830 subject id out of  1000
# Now processing  831 subject id out of  1000
# Now processing  832 subject id out of  1000
# Now processing  833 subject id out of  1000
# Now processing  834 subject id out of  1000
# Now processing  835 subject id out of  1000
# Now processing  836 subject id out of  1000
# Now processing  837 subject id out of  1000
# Now processing  838 subject id out of  1000
# Now processing  839 subject id out of  1000
# Now processing  840 subject id out of  1000
# Now processing  841 subject id out of  1000
# Now processing  842 subject id out of  1000
# Now processing  843 subject id out of  1000
# Now processing  844 subject id out of  1000
# Now processing  845 subject id out of  1000
# Now processing  846 subject id out of  1000
# Now processing  847 subject id out of  1000
# Now processing  848 subject id out of  1000
# Now processing  849 subject id out of  1000
# Now processing  850 subject id out of  1000
# Now processing  851 subject id out of  1000
# Now processing  852 subject id out of  1000
# Now processing  853 subject id out of  1000
# Now processing  854 subject id out of  1000
# Now processing  855 subject id out of  1000
# Now processing  856 subject id out of  1000
# Now processing  857 subject id out of  1000
# Now processing  858 subject id out of  1000
# Now processing  859 subject id out of  1000
# Now processing  860 subject id out of  1000
# Now processing  861 subject id out of  1000
# Now processing  862 subject id out of  1000
# Now processing  863 subject id out of  1000
# Now processing  864 subject id out of  1000
# Now processing  865 subject id out of  1000
# Now processing  866 subject id out of  1000
# Now processing  867 subject id out of  1000
# Now processing  868 subject id out of  1000
# Now processing  869 subject id out of  1000
# Now processing  870 subject id out of  1000
# Now processing  871 subject id out of  1000
# Now processing  872 subject id out of  1000
# Now processing  873 subject id out of  1000
# Now processing  874 subject id out of  1000
# Now processing  875 subject id out of  1000
# Now processing  876 subject id out of  1000
# Now processing  877 subject id out of  1000
# Now processing  878 subject id out of  1000
# Now processing  879 subject id out of  1000
# Now processing  880 subject id out of  1000
# Now processing  881 subject id out of  1000
# Now processing  882 subject id out of  1000
# Now processing  883 subject id out of  1000
# Now processing  884 subject id out of  1000
# Now processing  885 subject id out of  1000
# Now processing  886 subject id out of  1000
# Now processing  887 subject id out of  1000
# Now processing  888 subject id out of  1000
# Now processing  889 subject id out of  1000
# Now processing  890 subject id out of  1000
# Now processing  891 subject id out of  1000
# Now processing  892 subject id out of  1000
# Now processing  893 subject id out of  1000
# Now processing  894 subject id out of  1000
# Now processing  895 subject id out of  1000
# Now processing  896 subject id out of  1000
# Now processing  897 subject id out of  1000
# Now processing  898 subject id out of  1000
# Now processing  899 subject id out of  1000
# Now processing  900 subject id out of  1000
# Now processing  901 subject id out of  1000
# Now processing  902 subject id out of  1000
# Now processing  903 subject id out of  1000
# Now processing  904 subject id out of  1000
# Now processing  905 subject id out of  1000
# Now processing  906 subject id out of  1000
# Now processing  907 subject id out of  1000
# Now processing  908 subject id out of  1000
# Now processing  909 subject id out of  1000
# Now processing  910 subject id out of  1000
# Now processing  911 subject id out of  1000
# Now processing  912 subject id out of  1000
# Now processing  913 subject id out of  1000
# Now processing  914 subject id out of  1000
# Now processing  915 subject id out of  1000
# Now processing  916 subject id out of  1000
# Now processing  917 subject id out of  1000
# Now processing  918 subject id out of  1000
# Now processing  919 subject id out of  1000
# Now processing  920 subject id out of  1000
# Now processing  921 subject id out of  1000
# Now processing  922 subject id out of  1000
# Now processing  923 subject id out of  1000
# Now processing  924 subject id out of  1000
# Now processing  925 subject id out of  1000
# Now processing  926 subject id out of  1000
# Now processing  927 subject id out of  1000
# Now processing  928 subject id out of  1000
# Now processing  929 subject id out of  1000
# Now processing  930 subject id out of  1000
# Now processing  931 subject id out of  1000
# Now processing  932 subject id out of  1000
# Now processing  933 subject id out of  1000
# Now processing  934 subject id out of  1000
# Now processing  935 subject id out of  1000
# Now processing  936 subject id out of  1000
# Now processing  937 subject id out of  1000
# Now processing  938 subject id out of  1000
# Now processing  939 subject id out of  1000
# Now processing  940 subject id out of  1000
# Now processing  941 subject id out of  1000
# Now processing  942 subject id out of  1000
# Now processing  943 subject id out of  1000
# Now processing  944 subject id out of  1000
# Now processing  945 subject id out of  1000
# Now processing  946 subject id out of  1000
# Now processing  947 subject id out of  1000
# Now processing  948 subject id out of  1000
# Now processing  949 subject id out of  1000
# Now processing  950 subject id out of  1000
# Now processing  951 subject id out of  1000
# Now processing  952 subject id out of  1000
# Now processing  953 subject id out of  1000
# Now processing  954 subject id out of  1000
# Now processing  955 subject id out of  1000
# Now processing  956 subject id out of  1000
# Now processing  957 subject id out of  1000
# Now processing  958 subject id out of  1000
# Now processing  959 subject id out of  1000
# Now processing  960 subject id out of  1000
# Now processing  961 subject id out of  1000
# Now processing  962 subject id out of  1000
# Now processing  963 subject id out of  1000
# Now processing  964 subject id out of  1000
# Now processing  965 subject id out of  1000
# Now processing  966 subject id out of  1000
# Now processing  967 subject id out of  1000
# Now processing  968 subject id out of  1000
# Now processing  969 subject id out of  1000
# Now processing  970 subject id out of  1000
# Now processing  971 subject id out of  1000
# Now processing  972 subject id out of  1000
# Now processing  973 subject id out of  1000
# Now processing  974 subject id out of  1000
# Now processing  975 subject id out of  1000
# Now processing  976 subject id out of  1000
# Now processing  977 subject id out of  1000
# Now processing  978 subject id out of  1000
# Now processing  979 subject id out of  1000
# Now processing  980 subject id out of  1000
# Now processing  981 subject id out of  1000
# Now processing  982 subject id out of  1000
# Now processing  983 subject id out of  1000
# Now processing  984 subject id out of  1000
# Now processing  985 subject id out of  1000
# Now processing  986 subject id out of  1000
# Now processing  987 subject id out of  1000
# Now processing  988 subject id out of  1000
# Now processing  989 subject id out of  1000
# Now processing  990 subject id out of  1000
# Now processing  991 subject id out of  1000
# Now processing  992 subject id out of  1000
# Now processing  993 subject id out of  1000
# Now processing  994 subject id out of  1000
# Now processing  995 subject id out of  1000
# Now processing  996 subject id out of  1000
# Now processing  997 subject id out of  1000
# Now processing  998 subject id out of  1000
# Now processing  999 subject id out of  1000

# %% [markdown]
# All of your predictions will be stored in
# ```
# prediction_array
# ```
